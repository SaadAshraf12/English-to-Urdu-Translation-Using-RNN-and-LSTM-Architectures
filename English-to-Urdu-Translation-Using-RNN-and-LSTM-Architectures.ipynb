# %%
# !pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.5)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# ## Removing NAN columns

# %%
import pandas as pd
df = pd.read_excel("parallel-corpus.xlsx")
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.to_excel("cleaned_file.xlsx", index=False)
print("Unnamed columns removed and file saved as 'cleaned_file.xlsx'.")
# Out:
# Unnamed columns removed and file saved as 'cleaned_file.xlsx'.

# %%
df.head(15)
# Out:
#                                            SENTENCES   \
# 0              How can I communicate with my parents?
# 1                            How can I make friends?’
# 2                               Why do I get so sad?’
# 3   If you’ve asked yourself such questions, you’r...
# 4   Depending on where you’ve turned for guidance,...
# 5   To help young people get solid advice they can...
# 6   in January1982. Decades later, the series stil...
# 7   Each article is the product of extensive resea...
# 8   The book you now hold was originally published...
# 9   However, the chapters have been completely rev...
# 10  Questions Young People Ask—Answers That Work, ...
# 11                                        The result?
# 12   “I just went to my bedroom and cried some more!”
# 13   On the other hand, sometimes you might prefer...
# 14         “I talk to my parents about many subjects,
#
#                                               MEANING
# 0                  میں اپنے والدین سے کیسے بات کروں ؟
# 1                              میں دوست کیسے بنائوں ؟
# 2                            میں اتنا اداس کیوں ہوں؟.
# 3   اگر آپ نے اپنے آپ سے ایسے سوالات کیے ہیں، تو آ...
# 4    اس بات پر منحصر ہے کہ آپ رہنمائی کے لیے کہاں ...
# 5   نوجوانوں کو ٹھوس مشورے حاصل کرنے میں مدد کرنے ...
# 6   8 جنوری 1982۔ دہائیوں کے بعد، سیریز اب بھی ایک...
# 7   درحقیقت، اس بات کا تعین کرنے کے لیے کہ نوجوان ...
# 8   جو کتاب آپ کے پاس ہے وہ اصل میں 1989 میں شائع ...
# 9                                                 ...
# 10  نوجوان لوگ جو سوالات پوچھتے ہیں — جوابات جو کا...
# 11                                             نتیجہ؟
# 12  میں ابھی اپنے سونے کے کمرے میں گیا اور کچھ اور...
# 13   دوسری طرف، بعض اوقات آپ اپنے والدین کے سامنے ...
# 14                                                ...

# %%
# !pip install LughaatNLP
# Out:
# Requirement already satisfied: LughaatNLP in /usr/local/lib/python3.10/dist-packages (1.0.6)
# Requirement already satisfied: python-Levenshtein in /usr/local/lib/python3.10/dist-packages (from LughaatNLP) (0.26.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from LughaatNLP) (2.17.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from LughaatNLP) (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from LughaatNLP) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from LughaatNLP) (1.13.1)
# Requirement already satisfied: gtts in /usr/local/lib/python3.10/dist-packages (from LughaatNLP) (2.5.3)
# Requirement already satisfied: SpeechRecognition in /usr/local/lib/python3.10/dist-packages (from LughaatNLP) (3.10.4)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from LughaatNLP) (0.25.1)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from gtts->LughaatNLP) (2.32.3)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.10/dist-packages (from gtts->LughaatNLP) (8.1.7)
# Requirement already satisfied: Levenshtein==0.26.0 in /usr/local/lib/python3.10/dist-packages (from python-Levenshtein->LughaatNLP) (0.26.0)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /usr/local/lib/python3.10/dist-packages (from Levenshtein==0.26.0->python-Levenshtein->LughaatNLP) (3.10.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->LughaatNLP) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->LughaatNLP) (3.5.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from SpeechRecognition->LughaatNLP) (4.12.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->LughaatNLP) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->LughaatNLP) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow->LughaatNLP) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->LughaatNLP) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->LughaatNLP) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->LughaatNLP) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->LughaatNLP) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->LughaatNLP) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->LughaatNLP) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow->LughaatNLP) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->LughaatNLP) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow->LughaatNLP) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->LughaatNLP) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->LughaatNLP) (2.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->LughaatNLP) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->LughaatNLP) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow->LughaatNLP) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->LughaatNLP) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->LughaatNLP) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->LughaatNLP) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow->LughaatNLP) (13.9.2)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow->LughaatNLP) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow->LughaatNLP) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts->LughaatNLP) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts->LughaatNLP) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts->LughaatNLP) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts->LughaatNLP) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow->LughaatNLP) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow->LughaatNLP) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow->LughaatNLP) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow->LughaatNLP) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow->LughaatNLP) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow->LughaatNLP) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow->LughaatNLP) (0.1.2)

# %%
import pandas as pd
from tqdm import tqdm
import multiprocessing
from joblib import Parallel, delayed
import LughaatNLP

# %% [markdown]
# ## removing punctuation

# %%
import re

# Urdu punctuations
URDU_PUNCTUATIONS = ['\u200F', '\u200f', '۔', '٫', '٪', '؟', '،', ')', '(', '{', '}', '…', '...', '۔۔۔', '\u002F', '\u003F', '.']

def removing_punctuations(text):
    for punct in URDU_PUNCTUATIONS:
        text = text.replace(punct, " ")
    return text

for index, row in df.iterrows():
    urdu_text = row['MEANING']
    if isinstance(urdu_text, str):
        cleaned_text = removing_punctuations(urdu_text)
        df.at[index, 'MEANING'] = cleaned_text
    else:
        df.at[index, 'MEANING'] = ""
df.to_excel("cleaned_file.xlsx", index=False)
df.head(15)
# Out:
#                                            SENTENCES   \
# 0              How can I communicate with my parents?
# 1                            How can I make friends?’
# 2                               Why do I get so sad?’
# 3   If you’ve asked yourself such questions, you’r...
# 4   Depending on where you’ve turned for guidance,...
# 5   To help young people get solid advice they can...
# 6   in January1982. Decades later, the series stil...
# 7   Each article is the product of extensive resea...
# 8   The book you now hold was originally published...
# 9   However, the chapters have been completely rev...
# 10  Questions Young People Ask—Answers That Work, ...
# 11                                        The result?
# 12   “I just went to my bedroom and cried some more!”
# 13   On the other hand, sometimes you might prefer...
# 14         “I talk to my parents about many subjects,
#
#                                               MEANING
# 0                  میں اپنے والدین سے کیسے بات کروں
# 1                              میں دوست کیسے بنائوں
# 2                            میں اتنا اداس کیوں ہوں
# 3   اگر آپ نے اپنے آپ سے ایسے سوالات کیے ہیں  تو آ...
# 4    اس بات پر منحصر ہے کہ آپ رہنمائی کے لیے کہاں ...
# 5   نوجوانوں کو ٹھوس مشورے حاصل کرنے میں مدد کرنے ...
# 6   8 جنوری 1982  دہائیوں کے بعد  سیریز اب بھی ایک...
# 7   درحقیقت  اس بات کا تعین کرنے کے لیے کہ نوجوان ...
# 8   جو کتاب آپ کے پاس ہے وہ اصل میں 1989 میں شائع ...
# 9                                                 ...
# 10  نوجوان لوگ جو سوالات پوچھتے ہیں — جوابات جو کا...
# 11                                             نتیجہ
# 12  میں ابھی اپنے سونے کے کمرے میں گیا اور کچھ اور...
# 13   دوسری طرف  بعض اوقات آپ اپنے والدین کے سامنے ...
# 14                                                ...

# %%
import pandas as pd
df = pd.read_excel('cleaned_file.xlsx')
print(df.columns)
# Out:
# Index(['SENTENCES ', 'MEANING'], dtype='object')

# %%
import pandas as pd
import string
df = pd.read_excel('cleaned_file.xlsx')
df.columns = df.columns.str.strip()
print(df.columns)

def remove_punctuation(text):
    if isinstance(text, str):
        return text.translate(str.maketrans('', '', string.punctuation))
    return text
df['SENTENCES'] = df['SENTENCES'].astype(str).apply(remove_punctuation)
df.to_excel('cleaned_file.xlsx', index=False)
print("Punctuation removed and file saved as 'cleaned_file.xlsx'.")
# Out:
# Index(['SENTENCES', 'MEANING'], dtype='object')
# Punctuation removed and file saved as 'cleaned_file.xlsx'.

# %%
df.head()
# Out:
#                                            SENTENCES  \
# 0              How can I communicate with my parents
# 1                            How can I make friends’
# 2                               Why do I get so sad’
# 3  If you’ve asked yourself such questions you’re...
# 4  Depending on where you’ve turned for guidance ...
#
#                                              MEANING
# 0                 میں اپنے والدین سے کیسے بات کروں
# 1                             میں دوست کیسے بنائوں
# 2                           میں اتنا اداس کیوں ہوں
# 3  اگر آپ نے اپنے آپ سے ایسے سوالات کیے ہیں  تو آ...
# 4   اس بات پر منحصر ہے کہ آپ رہنمائی کے لیے کہاں ...

# %% [markdown]
# ## Removing Short Conversation

# %%
def has_few_words(text: str):
    words = text.split()
    return len(words) <= 3
df = df[~df['MEANING'].apply(lambda text: has_few_words(text) if isinstance(text, str) else True)]
df.to_excel('cleaned_file.xlsx', index=False)

# %%
df.head()
# Out:
#                                            SENTENCES  \
# 0              How can I communicate with my parents
# 1                            How can I make friends’
# 2                               Why do I get so sad’
# 3  If you’ve asked yourself such questions you’re...
# 4  Depending on where you’ve turned for guidance ...
#
#                                              MEANING
# 0                 میں اپنے والدین سے کیسے بات کروں
# 1                             میں دوست کیسے بنائوں
# 2                           میں اتنا اداس کیوں ہوں
# 3  اگر آپ نے اپنے آپ سے ایسے سوالات کیے ہیں  تو آ...
# 4   اس بات پر منحصر ہے کہ آپ رہنمائی کے لیے کہاں ...

# %%
import pandas as pd
df = pd.read_excel('cleaned_file.xlsx')
df.columns = df.columns.str.strip()
def remove_short_sentences(text, min_length=5):
    if isinstance(text, str):
        return text if len(text.split()) >= min_length else None
    return text
df['SENTENCES'] = df['SENTENCES'].apply(remove_short_sentences)
df = df.dropna(subset=['SENTENCES'])
df.to_excel('cleaned_file.xlsx', index=False)
print("Short sentences removed and file saved as 'cleaned_file.xlsx'.")
# Out:
# Short sentences removed and file saved as 'cleaned_file.xlsx'.

# %% [markdown]
# ## Tokenization

# %%
import pandas as pd
import LughaatNLP

df = pd.read_excel('cleaned_file.xlsx')

urdu_text_processing = LughaatNLP.LughaatNLP()
df['tokenized_text'] = None
def tokenize_and_update(df):
    for index, row in df.iterrows():
        tokens = urdu_text_processing.urdu_tokenize(row['MEANING'])
        df.at[index, 'tokenized_text'] = tokens
tokenize_and_update(df)
df.to_excel('cleaned_file.xlsx', index=False)
print(df[['SENTENCES', 'MEANING', 'tokenized_text']].head())
# Out:
#                                            SENTENCES  \
# 0              How can I communicate with my parents
# 1                            How can I make friends’
# 2                               Why do I get so sad’
# 3  If you’ve asked yourself such questions you’re...
# 4  Depending on where you’ve turned for guidance ...
#
#                                              MEANING  \
# 0                 میں اپنے والدین سے کیسے بات کروں
# 1                             میں دوست کیسے بنائوں
# 2                           میں اتنا اداس کیوں ہوں
# 3  اگر آپ نے اپنے آپ سے ایسے سوالات کیے ہیں  تو آ...
# 4   اس بات پر منحصر ہے کہ آپ رہنمائی کے لیے کہاں ...
#
#                                       tokenized_text
# 0           [میں, اپنے, والدین, سے, کیسے, بات, کروں]
# 1                          [میں, دوست, کیسے, بنائوں]
# 2                       [میں, اتنا, اداس, کیوں, ہوں]
# 3  [اگر, آپ, نے, اپنے, آپ, سے, ایسے, سوالات, کیے,...
# 4  [اس, بات, پر, منحصر, ہے, کہ, آپ, رہنمائی, کے, ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
df = pd.read_excel('cleaned_file.xlsx')
df['tokenized_sentences'] = None
def tokenize_sentences(df):
    for index, row in df.iterrows():
        tokens = word_tokenize(row['SENTENCES'])
        df.at[index, 'tokenized_sentences'] = tokens

tokenize_sentences(df)
df.to_excel('cleaned_file.xlsx', index=False)
print(df[['SENTENCES', 'tokenized_sentences']].head())
# Out:
#                                            SENTENCES  \
# 0              How can I communicate with my parents
# 1                            How can I make friends’
# 2                               Why do I get so sad’
# 3  If you’ve asked yourself such questions you’re...
# 4  Depending on where you’ve turned for guidance ...
#
#                                  tokenized_sentences
# 0      [How, can, I, communicate, with, my, parents]
# 1                    [How, can, I, make, friends, ’]
# 2                      [Why, do, I, get, so, sad, ’]
# 3  [If, you, ’, ve, asked, yourself, such, questi...
# 4  [Depending, on, where, you, ’, ve, turned, for...

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
# Load the data from the Excel file
df = pd.read_excel('cleaned_file.xlsx')

# Print the column names to check for mismatches
print("Columns in DataFrame:", df.columns.tolist())
# Out:
# Columns in DataFrame: ['SENTENCES', 'MEANING', 'tokenized_text', 'tokenized_sentences']

# %%
# Define necessary imports
import pandas as pd
import unicodedata
import re
import random

SOS_token = 0
EOS_token = 1

class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# Turn a Unicode string to plain ASCII
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    return s

# Read language data from the DataFrame
def readLangs(df, reverse=False):
    print("Reading lines...")
    pairs = []

    for _, row in df.iterrows():
        input_sentence = normalizeString(row['SENTENCES'])  # Use the correct column name
        output_sentence = normalizeString(row['MEANING'])   # Use the correct column name
        pairs.append([input_sentence, output_sentence])

    print("Lines read successfully")
    if reverse:
        pairs = [list(reversed(p)) for p in pairs]

    return pairs

# Filter pairs based on length
MAX_LENGTH = 30

def filterPair(p):
    return len(p[0].split(' ')) < MAX_LENGTH and \
           len(p[1].split(' ')) < MAX_LENGTH

def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]  # Apply filterPair to filter pairs

# Prepare the data
def prepareData(df, reverse=False):
    pairs = readLangs(df, reverse)
    print("Read %s sentence pairs" % len(pairs))
    pairs = filterPairs(pairs)
    print("Trimmed to %s sentence pairs" % len(pairs))
    input_lang = Lang('English')
    output_lang = Lang('Other Language')

    print("Counting words...")
    for pair in pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])

    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    return input_lang, output_lang, pairs

# Load the data from the Excel file
df = pd.read_excel('cleaned_file.xlsx')

# Prepare the data
input_lang, output_lang, pairs = prepareData(df, reverse=False)

# Ensure pairs is a list of lists

# Print a random sample of the pairs
print(random.choice(pairs))
# Out:
# Reading lines...
# Lines read successfully
# Read 22037 sentence pairs
# Trimmed to 17817 sentence pairs
# Counting words...
# Counted words:
# English 11536
# Other Language 9747
# ['don’t paint the town red', 'شہر کو سرخ نہ رنگیں']

# %%
for pair in pairs:
  print(pair)
# Out:
# Streaming output truncated to the last 5000 lines.
# ['my second time delicious food do try the fillet', 'میری دوسری بار  سوادج کھانا  فلیٹ ازمايیں']
# ['best pocket friendly restaurant with finger licking food\nburgers and wings were the best', 'انگلی چاٹنے والے کھانے کے ساتھ بہترین پاکٹ فرینڈلی ریستوراں برگر اور پنکھ بہترین تھے']
# ['best gourmet burgers in town ❤', 'شہر میں بہترین نفیس برگر  ❤']
# ['awesome burgerstruly deserves a 5 star', 'بہت اچھے برگر  حقیقت میں 5 اسٹار کے مستحق ہیں ! !']
# ['excellent taste perfect ambiance love the interior\nfood quality is superb and unbelievably cheap', 'بہترین ذايقہ  کامل ماحول  داخلہ سے محبت کرتا ہوں  کھانے کا معیار شاندار ہے  اور ناقابل یقین حد تک سستا']
# ['best food quality in reasonable price', 'مناسب قیمت میں کھانے کا بہترین معیار']
# ['taste is very good but service is unsatisfied', 'ذايقہ بہت اچھا ہے لیکن سروس غیر مطمين ہے']
# ['mutton karahi is very special also lighting is even batter', 'مٹن کرہی بہت خاص ہے اور لايٹنگ بھی بیٹر ہے']
# ['superb very testy food no need to goings highway', 'شاندار بہت ٹیسٹی کھانا ہايی وے پر جانے کی ضرورت نہیں ہے']
# ['translated by google karahi and kabab\n\noriginal\nkarahi and kabab', 'گوگل کے ذریعہ ترجمہ کیا گیا  کراہی اور کباب  اصل  کراہی اور کباب']
# ['all is good except the taste in food', 'کھانے میں ذايقہ کے علاوہ سب اچھا ہے']
# ['good food with friendly service', 'دوستانہ خدمت کے ساتھ اچھا کھانا']
# ['very courteous staff excellent dumba karhai', 'بہت شايستہ عملہ  بہترین ڈمبا کرہايی']
# ['wow very good test and really enjoyed', 'واہ بہت اچھا ٹیسٹ اور واقعی مزہ ایا']
# ['taste is really good and kahwa is even more good after meal', 'ذايقہ واقعی اچھا ہے  اور قہوہ کھانے کے بعد اور بھی اچھا ہے']
# ['mutton karahi was delicious and table service is good little bit expensive overall good experience', 'مٹن کراہی مزیدار تھی اور ٹیبل سروس اچھی تھوڑی مہنگی ہے   مجموعی طور پر اچھا تجربہ']
# ['translated by google behtreen taste\n\noriginal\nbehtreen taste', 'گوگل کے ذریعہ ترجمہ شدہ  بہترین ذايقہ  اصل  بہترین ذايقہ']
# ['the food is awesome i suggest everyone to try it', 'کھانا بہت اچھا ہے میں ہر ایک کو اسے ازمانے کا مشورہ دیتا ہوں']
# ['malai boti was outstanding ❤', 'ملايی بوٹی شاندار تھی ❤']
# ['delicious food excellent atmosphere recommended', 'مزیدار کھانا  بہترین ماحول  تجویز کردہ']
# ['best mutton karahi in t0wn', 't0wn میں بہترین مٹن کراہی']
# ['translated by google equal\n\noriginal\nlik', 'گوگل کے ذریعہ ترجمہ کردہ  برابر  اصل  لايک']
# ['wonderful experience with family suitable atmosphere to spend precious time with family', 'خاندان کے ساتھ قیمتی وقت گزارنے کے لیے خاندانی مناسب ماحول کے ساتھ شاندار تجربہ']
# ['quick service beef afghani boti is the best', 'فوری سروس  بیف افغانی بوٹی بہترین ہے']
# ['just visited tonight tried their charsi karahi still i say best one in town', 'ابھی اج رات تشریف لايے  ان کی چرسی کراہی کی کوشش کی  پھر بھی میں کہتا ہوں کہ شہر میں سب سے بہتر ہے']
# ['food and service is good due to ramzan no ruch found', 'کھانا اور سروس اچھی ہے  رمضان کی وجہ سے کويی روچ نہیں ملا']
# ['khyber shinwari is a little good place to dine in motton karraie and kaabli boti we tried were very delicious', 'خیبر شنواری کھانے کے لیے تھوڑی اچھی جگہ ہے  موٹن کرايی اور کابلی بوٹی  ہم نے کوشش کی کہ بہت لذیذ تھے']
# ['translated by google very good masha allah\nbut the waiters were too smart\n\noriginal\nبہت اچھا ماشاءاللہ\nمگر ویٹرز ضرورت سے زیادہ ہوشیار تھے', 'گوگل کا ترجمہ  بہت خوب ماشاء اللہ لیکن ویٹر بہت ہوشیار تھے  اصل  بہت اچھے ماشاء اللہ لیکن ویٹرز زیادہ ہوشیار تھے']
# ['taste is excellent safe secure and neat  clean environment', 'ذايقہ بہترین ہے  محفوظ  محفوظ اور صاف ستھرا ماحول']
# ['its osm and osm settaf and foods i was really enjoyeted', 'اس کے osm اور osm settaf اور کھانے کی اشیاء سے مجھے بہت لطف ایا']
# ['be sure to visit here for the best and tastiest food', 'بہترین اور لذیذ ترین کھانے کے لیے یہاں ضرور تشریف لايیں']
# ['such a good foods and taste and very good staff and beautiful invoirment', 'اتنا اچھا کھانا اور ذايقہ اور بہت اچھا عملہ اور خوبصورت انووايرمنٹ']
# ['it was really good experience', 'یہ واقعی اچھا تجربہ تھا']
# ['food is good water behavior is nice', 'کھانا اچھا ہے پانی کا برتاو اچھا ہے']
# ['goat karahi taste is 1010 full marks', 'بکری کراہی کا ذايقہ 10 10 مکمل نمبر ہے']
# ['good taste and every thing was ok', 'اچھا ذايقہ اور ہر چیز ٹھیک تھی']
# ['translated by google delicious namkeen boti and namkeen karahi\n\noriginal\ndelicious namkeen boti and namkeen karahi', 'گوگل کے ذریعہ ترجمہ کیا گیا  مزیدار نمکین بوٹی اور نمکین کراہی  اصل  مزیدار نمکین بوٹی اور نمکین کراہی']
# ['the staff is good plus the view is lit', 'عملہ اچھا ہے اور منظر روشن ہے']
# ['best place for chicken karahi and chapli kabab never order their shahi tikka its a ripoff', 'چکن کراہی کے لیے بہترین جگہ  اور چپلی کباب  کبھی بھی ان کے شاہی ٹکے کا ارڈر نہ دیں']
# ['shinwari karahi was good 2200kg\n3k 4 persons meals', 'شنواری کراہی اچھی تھی  2200 کلوگرام 3k  4 افراد کا کھانا']
# ['nice taste  good family seating arrangement', 'اچھا ذايقہ فیملی کے بیٹھنے کا اچھا انتظام']
# ['tried tikka and afghani namkeen boti boti was good but tikka was totally pheeka just like a boiled chicken', 'ٹکا اور افغانی نمکین بوٹی کی کوشش کی  بوٹی اچھی تھی لیکن ٹکا بالکل پھیکا تھا  بالکل ابلی ہويی مرغی کی طرح']
# ['kabab  chinese was awesome but karhai average', 'کباب اور چاينیز لاجواب تھے لیکن کرہايی اوسط']
# ['they should add rice dish like biryani etc in their menu', 'انہیں چاول کی ڈش جیسے بریانی وغیرہ کو اپنے مینو میں شامل کرنا چاہیے']
# ['best place to have desi food in karachi', 'کراچی میں دیسی کھانے کے لیے بہترین جگہ']
# ['very bad taste edible oil like engine oil', 'بہت خراب ذايقہ خوردنی تیل جیسا کہ انجن ايل']
# ['taste was good ambiance was same as highway best alternative of highway', 'ذايقہ اچھا تھا  ماحول ہايی وے کے بہترین متبادل جیسا تھا']
# ['mutton peshawari karahi is must have', 'مٹن پشاوری کراہی ضرور ہونی چاہیے']
# ['superb taste and good serving', 'شاندار ذايقہ اور اچھی سرونگ']
# ['its a very tasty food and quality', 'یہ بہت لذیذ اور معیاری کھانا ہے']
# ['namkin boti and pilauo its awesome', 'نمکین بوٹی اور پیلاو یہ لاجواب ہے']
# ['translated by google karachi satta dollars to sector 4\n\noriginal\nkarachi satta dollars to sector 4', 'گوگل کا ترجمہ  کراچی سٹا ڈالر سیکٹر 4 سے  اصل  کراچی سٹا ڈالر سیکٹر 4']
# ['nice open place to eat', 'کھانے کے لیے اچھی کھلی جگہ']
# ['waiting is worthy lamb barbeque is awesome such wonderful marinated meat soft', 'انتظار کرنے کے قابل ہے  میمنے کی باربی کیو لاجواب ہے  ایسا شاندار میرینیٹ شدہ گوشت  نرم']
# ['karhai is good\nservice good\nthey dnt have tea', 'کرہايی اچھی سروس اچھی ہے  ان کے پاس چايے نہیں ہے']
# ['good food but expensive however it can be visited sometime', 'اچھا کھانا لیکن مہنگا ہے  تاہم کبھی کبھی اس کا دورہ کیا جا سکتا ہے']
# ['best  place and delicious food  but as my experience    weight  and after serve  weight   unsatisfied', 'بہترین جگہ اور مزیدار کھانا   لیکن میرے تجربے کے مطابق  وزن اور سرو کرنے کے بعد وزن  غیر مطمين']
# ['best afghani boti in town', 'شہر میں بہترین افغانی بوٹی']
# ['translated by google accha hotel he khana bhi acha he\n\noriginal\naccha hotel he khana bhi acha he', 'گوگل کا ترجمہ  اچھا ہوٹل وہ کھانا بھی اچھا وہ  اصل  اچھا ہوٹل وہ کھانا بھی اچھا ہے']
# ['food was good ambiance is just ok', 'کھانا اچھا تھا ماحول ٹھیک ہے']
# ['nic place and teasty food', 'اچھی جگہ اور لذیذ کھانا']
# ['had an amazing experience atmosphere was very pleasant everything was perfectly managed\nfood 1010\nambiance 1010', 'ایک حیرت انگیز تجربہ تھا  ماحول بہت خوشگوار تھا  سب کچھ بالکل منظم تھا  کھانا 10 10 ماحول 10 10']
# ['good traditional desi food in affordable price', 'سستی قیمت میں اچھے روایتی دیسی کھانے']
# ['the worst balochi tikka never buy balochi tikka from khyber shinwari', 'بدترین بلوچی ٹکا  کبھی بھی خیبر شنواری سے بلوچی ٹکا نہ خریدیں']
# ['translated by google choose east ha\n\noriginal\nzabar east ha', 'گوگل کے ذریعہ ترجمہ شدہ  مشرقی ہا  اصل  زبار مشرقی ہا کا انتخاب کریں']
# ['awsome taste specifically chapel kabab and mutton kadhai', 'شاندار ذايقہ خاص طور پر چپل کباب اور مٹن کدھايی']
# ['its ok  not bad  good value for money', 'یہ ٹھیک ہے  برا نہیں  پیسے کی اچھی قیمت']
# ['pathetic food\n\nsemi cooked even after 40 minutes of order', 'قابل رحم کھانا ارڈر کے 40 منٹ بعد بھی نیم پکایا گیا']
# ['v well the taste was fantastic osm full of spicy  delicious', 'اچھی طرح سے ذايقہ لاجواب osm سے بھرا ہوا مزیدار تھا']
# ['love their mutton ribs and karahi', 'ان کے مٹن کی پسلیاں اور کراہی سے پیار کریں']
# ['the food was too yummy  recommended', 'کھانا بہت لذیذ تجویز کیا گیا تھا']
# ['translated by google beef spring is good\n\noriginal\nبیف بہاری بوٹی اچھی ہے', 'گوگل کا ترجمہ  بیف بہار اچھا ہے  اصل  بیف بہاری بوٹی اچھی ہے']
# ['translated by google al rehman motors\n\noriginal\nal rehman motors', 'گوگل کے ذریعہ ترجمہ شدہ  الرحمن موٹرز  اصل  الرحمن موٹرز']
# ['open to sky and good sitting capasity fast service but the taste was horrible\ni will request to managment to improve taste', 'اسمان پر کھلا اور اچھی بیٹھنے کی صلاحیت تیز رفتار سروس لیکن ذايقہ خوفناک تھا میں ذايقہ کو بہتر بنانے کے ليے انتظامیہ سے درخواست کروں گا']
# ['translated by google intahai baykar karahi nakis gost\n\noriginal\nintahai baykar karahi nakis gost', 'گوگل کے ذریعے ترجمہ کیا گیا  انتہايی بے کار کراہی نقس گوست']
# ['the food was really goodhighly recommended', 'کھانا واقعی اچھا تھا     انتہايی سفارش کی گيی تھی']
# ['malai boti was good  seekh kabab was not good  shinwari karhai was just ok only', 'ملايی بوٹی اچھی تھی ! سیخ کباب اچھا نہ تھا  شنواری کرہايی بس ٹھیک تھی ! !']
# ['translated by google entire\n\noriginal\nتمام', 'گوگل کے ذریعہ ترجمہ شدہ  پوری  اصل  تمام']
# ['the food is not so tasty', 'کھانا اتنا لذیذ نہیں ہوتا']
# ['okay food not so great', 'ٹھیک ہے کھانا اتنا اچھا نہیں']
# ['delicious food nice servings cool environment i really enjoyed with family', 'مزیدار کھانا اچھا سرونگ ٹھنڈا ماحول جس کا میں نے فیملی کے ساتھ واقعی لطف اٹھایا']
# ['very bad experience tasteless food  too expensive  bad serving', 'بہت برا تجربہ  بے ذايقہ کھانا بہت مہنگا برا سرونگ']
# ['translated by google zaberdust\n\noriginal\nzaberdust', 'گوگل کے ذریعہ ترجمہ کیا گیا  zaberdust  اصل  zaberdust']
# ['good food quality specialist is chicken karahi and afghani boti overall good environment', 'کھانے کی اچھی کوالٹی  ماہر چکن کراہی  اور افغانی بوٹی  مجموعی طور پر اچھا ماحول']
# ['different taste with good environment', 'اچھے ماحول کے ساتھ مختلف ذايقہ']
# ['superb and affordable pricesservice is good keep it up', 'شاندار اور سستی قیمتیں  خدمت اچھی ہے  اسے جاری رکھیں']
# ['great taste specially mutton\nand have good service', 'بہت اچھا ذايقہ خاص طور پر مٹن  اور اچھی سروس ہے']
# ['wonderful place for family get together', 'فیملی اکٹھے ہونے کے لیے شاندار جگہ']
# ['food was okish service needs considerable improvement good hangout place', 'کھانا اچھا تھا  سروس میں کافی بہتری کی ضرورت ہے   اچھی ہینگ اوٹ جگہ']
# ['i visited that area  but did not have any thing  i visited nursery adjasent to that', 'میں نے اس علاقے کا دورہ کیا لیکن میرے پاس ایسی کويی چیز نہیں تھی جس سے ملحقہ نرسری میں گیا تھا']
# ['translated by google no taste\n\noriginal\nno taste', 'گوگل کے ذریعہ ترجمہ کردہ  کويی ذايقہ نہیں  اصل  کويی ذايقہ نہیں']
# ['translated by google good afghan boti and motton makhan karahai\n\noriginal\ngood afgani boti and motton makhan karahai', 'گوگل کے ذریعہ ترجمہ کیا گیا  اچھی افغان بوٹی اور موٹن مکھن کرہايی  اصل  اچھی افغانی بوٹی اور موٹن مکھن کرہايی']
# ['good environment best test of mutton karai chicken as well', 'اچھا ماحول مٹن کرايی چکن کا بھی بہترین ٹیسٹ']
# ['very good food taste nice sitting cleanness price a bit high but over all a good restaurant', 'کھانے کا بہت اچھا ذايقہ  بیٹھنے کی اچھی صفايی  قیمت تھوڑی زیادہ لیکن سب سے بڑھ کر ایک اچھا ریستوراں']
# ['foods very deliciousservice was good', 'کھانے بہت لذیذ ہیں  سروس اچھی تھی']
# ['translated by google zabardast\n\noriginal\nzabardast', 'گوگل کے ذریعے ترجمہ کیا گیا  zabardast  اصل  zabardast']
# ['delicious and tasty food held in the place', 'جگہ جگہ لذیذ اور لذیذ کھانے کا اہتمام کیا گیا']
# ['best afghani boti in town', 'شہر میں بہترین افغانی بوٹی']
# ['translated by google mutton karahi and kabab bhut zaiqedar hein\n\noriginal\nmutton karahi and kabab bhut zaiqedar hein', 'گوگل کے ذریعے ترجمہ کیا گیا  مٹن کراہی اور کباب بٹ ذیقدار ہین  اصل  مٹن کرہی اور کباب بٹ ذیقدار ہین']
# ['great place such a nice view service is very good   but food is expensive', 'عمدہ جگہ  اتنی اچھی ویو سروس بہت اچھی ہے  لیکن کھانا مہنگا ہے']
# ['good for only karhai purpose', 'صرف کرہايی مقصد کے لیے اچھا ہے']
# ['specious basement is ideal for 25 person', 'مخصوص تہہ خانے 25+ افراد کے ليے مثالی ہے']
# ['awesome food desi mutton karahi lamb karahi mutton champ damb bukh ❤', 'لاجواب کھانا دیسی مٹن کراہی میمنا کراہی مٹن چمپ ڈمب بک ❤']
# ['its very good taste and we all like this type of sitting view', 'یہ بہت اچھا ذايقہ ہے اور ہم سب کو اس قسم کے بیٹھنے کا نظارہ پسند ہے']
# ['good meal\nwell trained staff', 'اچھا کھانا اچھا تربیت یافتہ عملہ']
# ['good taste and good service', 'اچھا ذايقہ اور اچھی سروس']
# ['fresh food without any cheap masalas  great test', 'بغیر کسی سستے مسالے کے تازہ کھانا   زبردست ٹیسٹ']
# ['translated by google raeta bohot acha ha\n\noriginal\nraeta bohot acha ha', 'گوگل کے ذریعہ ترجمہ کیا گیا  ریتا بوہت اچھا ہا  اصل  ریتا بوہت اچھا ہے']
# ['translated by google ahaaa\n\noriginal\nahaaa', 'گوگل کے ذریعہ ترجمہ شدہ  اہا  اصل  اہا']
# ['its a must try restaurant awesome taste and not very expensive', 'یہ ریستوراں کا زبردست ذايقہ ضرور ازمايیں اور زیادہ مہنگا نہیں']
# ['last time the experience was amazing today i went again to celebrate my bd and everything was spoiled the food was below par', 'پچھلی بار کا تجربہ حیرت انگیز تھا  اج میں پھر اپنی بی ڈی منانے گیا تو سب کچھ بگڑ گیا  کھانا برابر نیچے تھا']
# ['very good place for dinner', 'رات کے کھانے کے لیے بہت اچھی جگہ']
# ['taste was good and environment also calm perfect place for friends gathering', 'ذايقہ بھی اچھا تھا اور ماحول بھی پرسکون  دوستوں کے اجتماع کے لیے بہترین جگہ']
# ['best karhai n boti ever', 'اب تک کا بہترین کرہايی ن بوٹی']
# ['translated by google maza nai raha ab\n\noriginal\nmaza nai raha ab', 'گوگل کے ذریعہ ترجمہ شدہ  مزہ نيی راہ اب  اصل  مزہ نيی راہ اب']
# ['best food for your tastebuds', 'اپ کے ذايقہ کے ليے بہترین کھانا']
# ['taste is good fast service', 'ذايقہ اچھا ہے  تیز سروس']
# ['taste us good but service is not good on weekend', 'ہمارا ذايقہ اچھا ہے لیکن ہفتے کے اخر میں سروس اچھی نہیں ہے']
# ['great arrangement fast service humble people and safe area', 'زبردست انتظام  تیز سروس  عاجز لوگ اور محفوظ علاقہ']
# ['the food are delicious and one of my favourite dish is achari mutton karahi  plz go taste it', 'کھانا مزیدار ہے  اور میری پسندیدہ ڈش میں سے ایک اچاری مٹن کراہی ہے  براہ کرم اسے چکھیں']
# ['mashaallah every things is very good\nquick service mashaallah\nwell done  ✔', 'ماشاءاللہ سب چیزیں بہت اچھی ہیں فوری سروس ماشاءاللہ شاباش ✔']
# ['awesome  experience for environmental and delicious test', 'ماحولیاتی اور مزیدار ٹیسٹ کے لیے زبردست تجربہ']
# ['food was good welcoming gesture by waiters need to improve time span between order to serve', 'کھانا اچھا تھا  ویٹروں کی طرف سے استقبالیہ اشارہ  خدمت کرنے کے ارڈر کے درمیان وقت کی مدت کو بہتر بنانے کی ضرورت ہے']
# ['food quality was not so good  this time in comparison  to my last visit in 2019', '2019 میں میرے اخری دورے کے مقابلے میں اس بار کھانے کا معیار اتنا اچھا نہیں تھا']
# ['tastes good but service was pathetic', 'ذايقہ اچھا ہے لیکن خدمت قابل رحم تھی']
# ['good services with good food', 'اچھے کھانے کے ساتھ اچھی خدمات']
# ['good quality of food with affordable price', 'مناسب قیمت کے ساتھ کھانے کی اچھی کوالٹی']
# ['good food and satisfactory services', 'اچھا کھانا اور تسلی بخش خدمات']
# ['excellent taste and service is really really excellent', 'بہترین ذايقہ اور خدمت واقعی بہت عمدہ ہے']
# ['translated by google improvement the meal  white chicken is good\n\noriginal\nبہتری۔ کھانا ۔ وايٹ چکن اچھا ملتا ہے', 'گوگل کے ذریعہ ترجمہ کردہ  بہتری  کھانا   سفید چکن اچھا ہے  اصل   کھانا  وايٹ چکن اچھا ہے']
# ['very good food poi t', 'بہت اچھا کھانا ہے']
# ['nice place but taste was normal', 'اچھی جگہ لیکن ذايقہ نارمل تھا']
# ['great dumba boti chicken karhai and lamb karhai  very fast service out order came in less then 15min', 'زبردست ڈمبا بوٹی  چکن کرہايی اور میمنے کی کرہايی ! بہت تیز سروس اوٹ ارڈر 15 منٹ سے بھی کم وقت میں ایا']
# ['ordered chicken and mutton karhai', 'چکن اور مٹن کرہايی کا ارڈر دیا']
# ['very tasty and delicious dinner from here', 'یہاں سے بہت لذیذ اور لذیذ ڈنر']
# ['translated by google best\n\noriginal\nبہترین', 'گوگل کے ذریعہ ترجمہ کیا گیا  بہترین  اصل  بہترین']
# ['we went there so many time it was nice but last visit it was so so', 'ہم وہاں کيی بار گيے یہ اچھا تھا  لیکن اخری دورہ ایسا ہی تھا']
# ['the test was fantastic we really enjoyed', 'ٹیسٹ لاجواب تھا ہم نے واقعی لطف اٹھایا']
# ['pishawari food is now available in north nazimabad same taste same service', 'پشاوری کھانا اب نارتھ ناظم اباد میں دستیاب ہے  ایک ہی ذايقہ ایک ہی خدمت']
# ['excwllent food  especially afghani boti is exceptional', 'شاندار کھانا  ! ! خاص طور پر افغانی بوٹی غیر معمولی ہے ! !']
# ['translated by google pahly wali bat nahen rahy\n\noriginal\npahly wali bat nahen rahy', 'گوگل کے ذریعے ترجمہ کیا گیا  پہلی والی بات نہیں رہی  اصل  پہلی والی بات نہیں رہی']
# ['best aghwani booti on town', 'بہترین اگوانی بوٹی   شہر میں']
# ['good and tasty dasi food', 'اچھا اور لذیذ داشی کھانا']
# ['best place for dine out', 'کھانے کے لیے بہترین جگہ']
# ['wonderful taste best mutton ribs outstanding namkeen boti and kehwaa', 'شاندار ذايقہ  بہترین مٹن پسلیاں  شاندار نمکین بوٹی اور کیوہ']
# ['open air space is quite good food is also fine overall a good place', 'کھلی ہوا کی جگہ کافی اچھی ہے  کھانا بھی ٹھیک ہے  مجموعی طور پر ایک اچھی جگہ']
# ['whats a nice weekend dinner  standard', 'ویک اینڈ ڈنر اور معیاری کیا ہے']
# ['taste is soso service is very slow and waiters are rigid', 'ذايقہ بہت اچھا ہے  سروس بہت سست ہے اور ویٹر سخت ہیں']
# ['charsi tikka and karahi is great', 'چرسی تکہ اور کراہی بہت اچھا ہے']
# ['very delicious brq special mutton dishes', 'بہت مزیدار brq خصوصی مٹن ڈشز']
# ['the food was very deliciuos n yummy dumba karahi and afhani boti was amazing and we really enjoyed it', 'کھانا بہت لذیذ اور لذیذ تھا  ڈمبا کراہی اور افہانی بوٹی حیرت انگیز تھی اور ہم نے واقعی اس کا لطف اٹھایا']
# ['very good local food ambience not so likely', 'بہت اچھا مقامی کھانے کا ماحول اتنا امکان نہیں ہے']
# ['great place for afghani and bar b q traditional seating with separate section for families', 'افغانی اور بار بی کیو کے لیے بہترین جگہ  خاندانوں کے لیے الگ سیکشن کے ساتھ روایتی بیٹھنے کی جگہ']
# ['moton karahi yummy and good service', 'موٹن کراہی مزیدار اور اچھی سروس']
# ['translated by google zabardast\n\noriginal\nzabardast', 'گوگل کے ذریعے ترجمہ کیا گیا  zabardast  اصل  zabardast']
# ['average food with high prices', 'اعلی قیمتوں کے ساتھ اوسط خوراک']
# ['good food and cooperating staff', 'اچھا کھانا اور تعاون کرنے والا عملہ']
# ['good ethics and delicious food', 'اچھی اخلاقیات اور مزیدار کھانا']
# ['superb afghani boti  dumba karahi  superb', 'شاندار  افغانی بوٹی  دنبہ کراہی  شاندار']
# ['nice place send time with family', 'خاندان کے ساتھ وقت گزارنے کی اچھی جگہ']
# ['excellent namkeen boti and mutton karahi', 'بہترین نمکین بوٹی اور مٹن کراہی']
# ['this is good spa e to eat food champain is good there kababs are also good', 'یہ کھانا کھانے کے لیے اچھا سپا ہے  چمپین اچھے ہیں وہاں کباب بھی اچھے ہیں']
# ['great place for a change', 'تبدیلی کے لیے بہترین جگہ']
# ['nice food desi cuisine charsi karahi is best for all setting arrangements families also can have fun', 'اچھا کھانا دیسی کھانا چرسی کراہی تمام ترتیب کے انتظامات کے لیے بہترین ہے اہل خانہ بھی مزے کر سکتے ہیں']
# ['karahi was not very tasty ordinary taste', 'کراہی زیادہ لذیذ نہیں تھی  عام ذايقہ']
# ['charsi karahi yummy n delicious', 'چرسی کراہی سوادج اور مزیدار']
# ['it is good but not as good as shaheenshinwari highway', 'یہ اچھی ہے لیکن شاہین شنواری ہايی وے جیسی اچھی نہیں']
# ['me full enjoy dinner with his friends in khyber shinwari restaurant\nthank you for batter sarvice of restaurant team', 'میں نے خیبر شنواری ریسٹورنٹ میں اپنے دوستوں کے ساتھ ڈنر کا بھرپور مزہ لیا ریسٹورنٹ ٹیم کی بہترین خدمات کا شکریہ']
# ['awsome food delicious white karhai', 'شاندار کھانا  مزیدار سفید کرہايی']
# ['translated by google the best quality food\n\noriginal\nبہترین معیار کا کھانا ہے', 'گوگل کے ذریعہ ترجمہ شدہ  بہترین معیار کا کھانا  اصل  بہترین معیار کا کھانا ہے']
# ['nyc for family and also friends\nall dishes are available there  bbq', 'فیملی اور دوستوں کے لیے بھی nyc تمام پکوان وہاں دستیاب ہیں + bbq']
# ['taste 910 sitting arrangement londay 1010 parking available rates okay quality 810 speciality namkeen boti', 'ذايقہ 9 10  بیٹھنے کا انتظام  لنڈی  10 10  پارکنگ دستیاب  قیمتیں ٹھیک  معیار 8 10  خاص نمکین بوٹی']
# ['i strongly recommend the people to visit this place for the sake of your taste buds for the taste you will never forgot', 'میں لوگوں سے پرزور مشورہ دیتا ہوں کہ اپ اپنی ذايقہ کی کلیوں کی خاطر اس جگہ کا دورہ کریں جس کا ذايقہ اپ کبھی نہیں بھولیں گے']
# ['never eat karahi from it home cooked is tastier then this', 'اس میں سے کڑھی کبھی نہ کھايیں  گھر کی پکايی اس سے زیادہ لذیذ ہوتی ہے']
# ['great taste must order green mutton karahi', 'بہت اچھا ذايقہ  گرین مٹن کراہی ضرور ارڈر کریں']
# ['restaurant is built on encroached childrens playground instead of a proper arrangement public sits on road island and even on the round about', 'ریستوراں بچوں کے کھیل کے میدان پر بنایا گیا ہے  عوام مناسب انتظامات کے بجايے سڑک کے جزیرے اور یہاں تک کہ چکر لگا کر بیٹھ جاتے ہیں']
# ['great foodvery tasty very good service', 'بہت اچھا کھانا  بہت لذیذ بہت اچھی سروس']
# ['charsi karahi is awesome and worth to eat good sitting arrangement as well', 'چرسی کراہی لاجواب اور کھانے کے لايق ہے  بیٹھنے کا بھی اچھا انتظام ہے']
# ['karachi darbar restaurant is very famous and popular for fast food like bar bq and many more items', 'کراچی دربار ریستوراں فاسٹ فوڈ جیسے بار بی کیو اور بہت سی اشیاء کے لیے بہت مشہور اور مقبول ہے']
# ['the afghani pulao taste was outstanding loved it', 'افغانی پلاو کا ذايقہ لاجواب تھا بہت پسند ایا   !']
# ['foods available in comportable price  for middle class peoples', 'متوسط \u200b\u200bطبقے کے لوگوں کے لیے مناسب قیمت پر کھانے کی اشیاء دستیاب ہیں']
# ['translated by google tests\n\noriginal\ntesty', 'گوگل کے ذریعہ ترجمہ شدہ  ٹیسٹ  اصل  ٹیسٹی']
# ['v v nice  love it', 'وی وی اچھا  اس سے محبت کرتے ہیں']
# ['translated by google hfd\n\noriginal\nhfd', 'گوگل کے ذریعہ ترجمہ شدہ  hfd  اصل  hfd']
# ['i love that because name is place by pakistan but need to improve', 'مجھے یہ پسند ہے کیونکہ نام پاکستان کی جگہ ہے لیکن اسے بہتر کرنے کی ضرورت ہے']
# ['good taste for all food  i like it', 'تمام کھانے کے لیے اچھا ذايقہ  مجھے یہ پسند ہے']
# ['best seafood in town just need to improve service thanks', 'شہر میں بہترین سمندری غذا  بس سروس کو بہتر بنانے کی ضرورت ہے  شکریہ']
# ['good lahori fish and fire chilli along with other fish', 'اچھی لاہوری مچھلی اور اگ مرچ دیگر مچھلیوں کے ساتھ']
# ['excellent food and good staff', 'بہترین کھانا اور اچھا عملہ']
# ['very tasty great service grilled fish specialist', 'بہت سوادج  زبردست سروس  گرلڈ فش سپیشلسٹ']
# ['fish and food quality is awesome', 'مچھلی اور کھانے کا معیار بہت اچھا ہے']
# ['taste and food quality is superb the only problem is the quality of seating arrangement you people charge no less than a high price restaurant', 'ذايقہ اور کھانے کا معیار شاندار ہے  مسيلہ صرف بیٹھنے کے انتظام کا معیار ہے  اپ لوگ کسی زیادہ قیمت والے ریستوراں سے کم قیمت نہیں لیتے']
# ['awsome food never eaten like this before with marvelous family environment', 'شاندار خاندانی ماحول کے ساتھ ایسا شاندار کھانا پہلے کبھی نہیں کھایا']
# ['translated by google great place\n\noriginal\nگریٹ جگه', 'گوگل کے ذریعہ ترجمہ کردہ  عظیم جگہ  اصل  گریٹ جگه']
# ['good service  very good food', 'اچھی سروس  بہت اچھا کھانا']
# ['grill prawns was too delicious', 'گرل جھینگے بہت لذیذ تھے']
# ['grilled n fried prawns wahh with fast n excellent serving staff', 'گرلڈ اور فرايیڈ جھینگے   واہ   تیز رفتار اور بہترین سرونگ اسٹاف کے ساتھ']
# ['accessible fresh and they handle any custom requests pleasantly', 'قابل رسايی  تازہ اور وہ کسی بھی حسب ضرورت درخواست کو خوش اسلوبی سے ہینڈل کرتے ہیں']
# ['nice place for eating fish', 'مچھلی کھانے کے لیے اچھی جگہ']
# ['nice place for fish lovers', 'مچھلی سے محبت کرنے والوں کے لیے اچھی جگہ']
# ['yummy food but service is not good', 'سوادج کھانا لیکن سروس اچھی نہیں ہے']
# ['its not bad\ntaste is good specially lahori', 'یہ برا نہیں ذايقہ اچھا ہے خاص طور پر لاہوری']
# ['very good taste of fish', 'مچھلی کا ذايقہ بہت اچھا ہے']
# ['its amazing test and quality', 'یہ حیرت انگیز ٹیسٹ اور معیار ہے']
# ['best place in karachi for sea food \nthumbs up\nhighly recommended', 'سی فوڈ تھمبس اپ کے لیے کراچی میں بہترین جگہ انتہايی سفارش کی جاتی ہے']
# ['nice food and service reasonable price', 'اچھا کھانا اور سروس مناسب قیمت']
# ['so much smell in fish  prawns  both are not fresh every time', 'مچھلی اور جھینگے میں اتنی خوشبو   دونوں ہر بار تازہ نہیں ہوتے']
# ['very nice fast food point', 'بہت اچھا فاسٹ فوڈ پواينٹ']
# ['good place for fish lover', 'مچھلی سے محبت کرنے والوں کے لیے اچھی جگہ']
# ['best place to have sea food grilled or fried', 'سی فوڈ گرل یا فرايی کرنے کے لیے بہترین جگہ']
# ['good place for fish lovers', 'مچھلی سے محبت کرنے والوں کے لیے اچھی جگہ']
# ['the grilled fish is just so good fried is not bad either', 'گرلڈ مچھلی صرف اتنی اچھی ہے  تلی ہويی بھی بری نہیں ہے']
# ['quetta wala fish shop perfect  cleanbest fish in kaachi', 'کويٹہ  والا فش شاپ پرفیکٹ کلین   کاچی کی بہترین مچھلی']
# ['try grilled prawns its just tasty', 'گرے ہويے جھینگے ازمايیں  یہ صرف مزیدار ہے']
# ['road side point for fresh delicious fish poor sitting arrangements', 'تازہ لذیذ مچھلی کے لیے روڈ سايیڈ پواينٹ  بیٹھنے کا ناقص انتظام']
# ['traditional very affordable fresh reliable delicious located opposite civic centre karachi', 'روایتی  بہت سستی  تازه  قابل اعتماد مزیدار  سوک سینٹر کراچی کے سامنے واقع ہے']
# ['4 star but in future 5', '4 ستارہ لیکن مستقبل میں 5']
# ['yummy fish specially their grilled fish', 'سوادج مچھلی خاص طور پر ان کی گرل مچھلی']
# ['translated by google great taste\n\noriginal\nsuper taste', 'گوگل کے ذریعہ ترجمہ کردہ  زبردست ذايقہ  اصل  سپر ذايقہ']
# ['translated by google umdah\n\noriginal\numdah', 'گوگل کے ذریعہ ترجمہ کیا گیا  امدہ  اصل  امدہ']
# ['by far the beat tasting fish in karachi gordon ramsey  could not make better fish it was wow', 'کراچی میں بیٹ چکھنے والی مچھلی اب تک گورڈن ریمسی اس سے بہتر مچھلی نہیں بناسکی  یہ واہ تھا']
# ['auwsam fish was very yummmy', 'اوصام   مچھلی بہت لذیذ تھی']
# ['all fish cover in same fish masala q k its very good taste', 'تمام مچھلیوں کو ایک ہی مچھلی کے مسالے میں ڈھانپ دیا جاتا ہے  qk اس کا ذايقہ بہت اچھا ہے']
# ['good taste i really enjoye', 'اچھا ذايقہ مجھے واقعی لطف اتا ہے']
# ['quantity and quality is getting worst', 'مقدار اور معیار بدترین ہو رہا ہے']
# ['fish and prawns were good in taste', 'مچھلی اور جھینگے ذايقے میں اچھے تھے']
# ['best finger fish in the town do visit with family as they have a nice sitting area', 'شہر کی بہترین فنگر فش فیملی کے ساتھ اتی ہیں کیونکہ ان کے پاس بیٹھنے کی جگہ اچھی ہے']
# ['great food but not perfect for my taste', 'بہت اچھا کھانا  لیکن میرے ذايقہ کے لیے کامل نہیں']
# ['translated by google eight taste\n\noriginal\nosam taste', 'گوگل کے ذریعہ ترجمہ کیا گیا  اٹھ ذايقہ  اصل  اسم ذايقہ']
# ['translated by google excilent\n\noriginal\nexcilent', 'گوگل کے ذریعہ ترجمہ شدہ  excilent  اصل  excilent']
# ['very yummy fish but too expensive', 'مچھلی بہت لذیذ ہے لیکن بہت مہنگی ہے']
# ['pamplat fish taste was fabulous', 'پامپلاٹ مچھلی کا ذايقہ لاجواب تھا']
# ['best fried fish in the town', 'شہر کی بہترین تلی ہويی مچھلی  ! !']
# ['grilled fish was were tasty  recommend', 'گرل کی ہويی مچھلی مزیدار تھی  سفارش کریں']
# ['translated by google dargah baba anath ali sha\n\noriginal\ndargah baba anath ali sha', 'گوگل کے ذریعہ ترجمہ شدہ  درگاہ بابا عنات علی شا  اصل  درگاہ بابا عنات علی شا']
# ['amazing taste and fresh fish n prawns', 'حیرت انگیز ذايقہ اور تازہ مچھلی اور جھینگے']
# ['food quality is fine pricing is high as it is road side dinning place which is uncomfortable', 'کھانے کا معیار ٹھیک ہے  قیمتیں زیادہ ہیں کیونکہ یہ سڑک کے کنارے کھانے کی جگہ ہے جو کہ غیر ارام دہ ہے']
# ['try boneless mushka the green chillies fried with spices is awesome', 'ہڈیوں کے بغیر مشکا ازمايیں  مصالحے کے ساتھ تلی ہويی ہری مرچ لاجواب ہے']
# ['open environment fish is not as good as it was', 'کھلے ماحول کی مچھلی اتنی اچھی نہیں ہے جتنی کہ تھی']
# ['complete range of sea food from grilled fish to fried prawns', 'سی فوڈ کی مکمل رینج  گرلڈ فش سے لے کر تلی ہويی جھینگے تک']
# ['translated by google good test sonehri fosh\n\noriginal\ngood test sonehri fosh', 'گوگل کے ذریعہ ترجمہ شدہ  اچھا ٹیسٹ سونہری فوش  اصل  اچھا ٹیسٹ سونہری فوش']
# ['awesome taste guyz must visit this place', 'حیرت انگیز ذايقہ والے لوگ اس جگہ کا دورہ ضرور کریں']
# ['great exeriance  finger fish was really tasteful', 'زبردست تجربہ  فنگر فش واقعی لذیذ تھی']
# ['good place for those who are fond of eating delicious grill fish', 'ان لوگوں کے لیے اچھی جگہ جو مزیدار گرل مچھلی کھانے کے شوقین ہیں']
# ['good place and good service prices keep on increasing in every visit almost 30 increase in two months', 'اچھی جگہ اور اچھی سروس  قیمتیں ہر دورے میں بڑھتی رہتی ہیں دو ماہ میں تقریبا 30% اضافہ']
# ['good quality fish ate after such long time', 'اچھی کوالٹی کی مچھلی اتنے عرصے کے بعد کھايی']
# ['good place for tasty fish and prawns', 'لذیذ مچھلی اور جھینگے کے لیے اچھی جگہ']
# ['bit expensive but love the taste', 'تھوڑا مہنگا لیکن ذايقہ پسند ہے']
# ['its a nice but busy get together place', 'یہ ایک اچھی لیکن مصروف جگہ ہے اکٹھے ہونے کے لیے']
# ['nice taste  enviorment feel free 2 enjoy with ur family', 'اچھا ذايقہ اور ماحول مفت محسوس کریں 2 اپنے خاندان کے ساتھ لطف اندوز ہوں']
# ['fish taste is very fabulous', 'مچھلی کا ذايقہ بہت شاندار ہے']
# ['translated by google good test \n\noriginal\ngood teste', 'گوگل کے ذریعہ ترجمہ شدہ  اچھا ٹیسٹ     اصل  اچھا ٹیسٹ']
# ['it was a great place', 'یہ ایک بہترین جگہ تھی']
# ['dangri fish grill is thier speciality try this must proper spices', 'ڈنگری فش گرل ان کی خاصیت ہے  یہ ضرور ازمايیں  مناسب مصالحہ']
# ['the taste of grill prawns and fish are excellent', 'گرل جھینگے اور مچھلی کا ذايقہ بہترین ہے']
# ['translated by google finger fish achi hai\n\noriginal\nfinger fish achi hai', 'گوگل کا ترجمہ  فنگر فش اچی ہے  اصل  فنگر فش اچی ہے']
# ['best fish ever i eaten bit expensive but finger liking fish recommends to all fishovers', 'اب تک کی بہترین مچھلی جو میں نے تھوڑی مہنگی کھايی ہے لیکن انگلیوں کو پسند کرنے والی مچھلی تمام مچھلیوں کے لیے تجویز کرتی ہے']
# ['translated by google very nice test culture fish\n\noriginal\nویری نايس ٹیسٹ کلچر فیش', 'گوگل کے ذریعہ ترجمہ شدہ  بہت عمدہ ٹیسٹ کلچر مچھلی  اصل  ویری نايس ٹیسٹ کلچر فیش']
# ['authentic taste in reasonable rates', 'مناسب نرخوں میں مستند ذايقہ']
# ['good fish point to eat sitting a bit casual', 'تھوڑا ارام دہ اور پرسکون بیٹھ کر کھانے کے ليے اچھا مچھلی نقطہ']
# ['good point for sea food', 'سمندری غذا کے لیے اچھا نقطہ']
# ['its good sitting arrangement was not proper specially for families service was also poor but but but food was fresh  tasty', 'یہ اچھا ہے  بیٹھنے کا انتظام خاص خاندانوں کے لیے مناسب نہیں تھا سروس بھی ناقص تھی لیکن کھانا تازہ اور لذیذ تھا']
# ['very very tasty and quality of fish especially grilled and lahori biscuit fish \ngood sitting arrangements', 'بہت ہی لذیذ اور معیاری مچھلی خصوصا گرل اور لاہوری بسکٹ مچھلی  بیٹھنے کا اچھا انتظام']
# ['translated by google what about danger barbecue fish\n\noriginal\nڈانگری باربی کیو فش کی کیا بات ہے', 'گوگل کے ذریعہ ترجمہ کیا گیا  ڈینجر باربی کیو مچھلی کے بارے میں کیا خیال ہے   اصل  ڈانگری باربی کیو فش کی بات ہے']
# ['fish was good in taste but chutni mint sauce was a total flop', 'مچھلی ذايقے میں اچھی تھی لیکن چٹنی  پودینے کی چٹنی  بالکل فلاپ تھی']
# ['average taste but poor service for take away', 'ٹیک دور کے لیے اوسط ذايقہ لیکن ناقص سروس']
# ['very fresh fish with great taste۔', 'بہت ذايقہ کے ساتھ بہت تازہ مچھلی']
# ['translated by google mazaidar\n\noriginal\nmazaidar', 'گوگل کے ذریعے ترجمہ شدہ  mazaidar  اصل  mazaidar']
# ['spicy and tastey fish\ni lyked it\nmust visit', 'مسالیدار اور لذیذ مچھلی میں نے اسے پسند کیا']
# ['love to eat again culture fish is best', 'دوبارہ کھانے کے ليے محبت  ثقافت مچھلی بہترین ہے']
# ['best place for fish lovers', 'مچھلی سے محبت کرنے والوں کے لیے بہترین جگہ']
# ['translated by google superbbb\n\noriginal\nsuperbbb', 'گوگل کے ذریعہ ترجمہ شدہ  سپر بی بی  اصل  سپر بی بی']
# ['convenient place for good taste fried and grilled fish in gulshan e iqbal karachi\ngreat taste and normal rates', 'گلشن اقبال کراچی میں اچھی ذايقہ والی تلی ہويی اور گرلڈ فش کے لیے اسان جگہ  عمدہ ذايقہ اور عام نرخ']
# ['very good test and frash ♥ love it', 'بہت اچھا ٹیسٹ اور فریش ♥ اسے پسند ہے']
# ['everything is fine but little bit expensive than others', 'سب کچھ ٹھیک ہے لیکن دوسروں کے مقابلے تھوڑا سا مہنگا ہے']
# ['their lahori fish is so tasty', 'ان کی لاہوری مچھلی بہت لذیذ ہوتی ہے']
# ['bestest place for grill iranian paplate i like it', 'گرل ایرانی پاپلیٹ کے لیے بہترین جگہ مجھے یہ پسند ہے']
# ['smart selection  very good price', 'اسمارٹ سلیکشن بہت اچھی قیمت ہے']
# ['never had that great taste of grilled fish and prawns', 'گرلڈ مچھلی اور جھینگے کا اتنا اچھا ذايقہ کبھی نہیں تھا']
# ['so testy fish i like it most', 'تو ٹیسٹی مچھلی مجھے یہ سب سے زیادہ پسند ہے']
# ['if you want to eat the good taste fish then visit with your family to this place and enjoy', 'اگر اپ اچھی ذايقہ والی مچھلی کھانا چاہتے ہیں تو اپنی فیملی کے ساتھ اس جگہ پر جايیں اور لطف اندوز ہوں']
# ['good food but setting area is not so  good', 'اچھا کھانا لیکن سیٹنگ ایریا اتنا اچھا نہیں ہے']
# ['excellent quality and taste\nbut the prices are bit high', 'بہترین معیار اور ذايقہ لیکن قیمتیں تھوڑی زیادہ ہیں']
# ['awsome taste try grilled red sniper fish heera', 'شاندار ذايقہ   گرلڈ ریڈ سنايپر فش  ہیرا  ازمايیں']
# ['good test and cheap rates of all food items', 'تمام کھانے پینے کی اشیاء کے اچھے ٹیسٹ اور سستے نرخ']
# ['too good environment and top quality food', 'بہت اچھا ماحول اور اعلی معیار کا کھانا']
# ['good fresh fish with reasonable seating space for families', 'خاندانوں کے بیٹھنے کی مناسب جگہ کے ساتھ اچھی تازہ مچھلی']
# ['nice place for a variety of fish with family r friends or team', 'فیملی کے دوستوں یا ٹیم کے ساتھ مختلف قسم کی مچھلیوں کے لیے اچھی جگہ']
# ['good taste and variety of fishes', 'اچھا ذايقہ اور مختلف قسم کی مچھلیاں']
# ['wow ultimate taste best fish  always eat irani paplet', 'واہ حتمی ذايقہ بہترین مچھلی   ہمیشہ ایرانی پاپلیٹ کھايیں']
# ['taste is awsomeand also enviroment', 'ذايقہ بھی اچھا ہے اور ماحول بھی']
# ['great food  but fish needs an improvement', 'بہت اچھا کھانا    لیکن مچھلی کو بہتری کی ضرورت ہے']
# ['good food but slow service', 'اچھا کھانا لیکن سست سروس']
# ['v yummy grilled chicken and peri burger with double patty after a along time had v delicious food  highly recommended', 'v مزیدار گرلڈ چکن اور ڈبل پیٹی کے ساتھ پیری برگر  کچھ وقت کے بعد مزیدار کھانے کی انتہايی سفارش کی گيی']
# ['best grilled chicken in ktown', 'k-town میں بہترین گرلڈ چکن']
# ['small but quaint the place has nice vibes too it not too cheap but not too expensive food is nice as well as the staff', 'چھوٹی لیکن عجیب  اس جگہ میں بھی خوبصورت وايبس ہیں  بہت سستا نہیں لیکن بہت مہنگا بھی نہیں  کھانا اچھا ہے اور عملہ بھی']
# ['good taste and service chicken wings and fries were great', 'اچھا ذايقہ اور سروس  چکن  پنکھ اور فرايز بہت اچھے تھے']
# ['grill and bbq chicken specialist', 'گرل اور بی بی کیو چکن ماہر']
# ['nice food but small place', 'اچھا کھانا لیکن چھوٹی جگہ']
# ['perry bites and wings are great', 'پیری کے کاٹنے اور پنکھ بہت اچھے ہیں  ! !']
# ['awesome ambiance very juicy food and service is outclass', 'بہت اچھا ماحول  بہت رسیلی کھانا اور سروس اوٹ کلاس ہے']
# ['really liked the mild mild flavour chicken', 'واقعی ہلکا ہلکا ذايقہ والا چکن پسند ایا']
# ['i like the peri peri chicken there only the quantity is not sufficient', 'مجھے وہاں پیری پیری چکن پسند ہے  صرف مقدار کافی نہیں ہے']
# ['tasteless food in townnot even fresh', 'شہر میں بے ذايقہ کھانا  تازہ بھی نہیں']
# ['food was awesome but a little costly', 'کھانا بہت اچھا تھا لیکن تھوڑا مہنگا تھا']
# ['best fast food for you if you are diet conscious', 'اگر اپ غذا کے بارے میں شعور رکھتے ہیں تو اپ کے لیے بہترین فاسٹ فوڈ']
# ['not as good as nandos but good in taste', 'نندو کی طرح اچھا نہیں لیکن ذايقہ میں اچھا ہے']
# ['at main tariq road 24 hours service', 'مین طارق روڈ پر 24 گھنٹے سروس']
# ['translated by google ooooo\n\noriginal\nooooo', 'گوگل کے ذریعہ ترجمہ شدہ  ooooo  اصل  ooooo']
# ['food is good but they really should add card services had to walk 10 minutes to take money out took the joy out of the food', 'کھانا اچھا ہے لیکن انہیں واقعی کارڈ کی خدمات شامل کرنی چاہيیں  پیسے نکالنے کے لیے 10 منٹ پیدل چلنا پڑا  کھانے سے خوشی چھین لی']
# ['finally i have found an alternative of nandos with better taste and better price tag', "اخر کار میں نے بہتر ذايقہ اور بہتر قیمت کے ساتھ nando's کا متبادل تلاش کر لیا ہے"]
# ['excellent food\nplease take care of your ambience n waiters should be trained well', 'بہترین کھانا    براہ کرم اپنے ماحول کا خیال رکھیں اور ویٹروں کو اچھی تربیت دی جايے']
# ['its like nandos cheaper version', 'یہ نینڈوس کے سستے ورژن کی طرح ہے']
# ['best peri chicken and fries specially the flaming hot flavour in chicken', 'بہترین پیری چکن اور فرايز خاص طور پر چکن میں جلتا ہوا گرم ذايقہ']
# ['good food but low service', 'اچھا کھانا لیکن کم سروس']
# ['delicious and juicy chicken burger   1010', 'مزیدار اور رسیلی چکن برگر 10 10']
# ['great experience chicken wings amazing', 'چکن ونگز کا شاندار تجربہ']
# ['good place for a grill and pizza', 'گرل اور پیزا کے لیے اچھی جگہ']
# ['good service n quality food', 'اچھی سروس اور معیاری کھانا']
# ['good burgers tasty and huygenic', 'اچھے برگر سوادج اور خوبصورت']
# ['great food stuff with awesome taste and service menu and taste of food', 'زبردست ذايقہ اور سروس مینو اور کھانے کے ذايقے کے ساتھ عمدہ کھانے کی چیزیں']
# ['had ordered the lunch deal food quality has dropped wings and burger patty were burnt and very dry very disappointing', 'لنچ ڈیل کا ارڈر دیا تھا  کھانے کا معیار گر گیا ہے  پنکھ اور برگر پیٹی جل چکے تھے اور بہت خشک تھے  بہت مایوس کن']
# ['translated by google ziada naheen pata\n\noriginal\nziada naheen pata', 'گوگل کے ذریعہ ترجمہ کیا گیا  زیدہ نہیں پتا  اصل  زیدہ نہیں پتا']
# ['good place to dine in with family and friends', 'خاندان اور دوستوں کے ساتھ کھانے کے لیے اچھی جگہ']
# ['healthy as well as tastier', 'صحت مند ہونے کے ساتھ ساتھ مزیدار بھی']
# ['they serve what nandos serve i found nandos food more richer in taste but overall ambience was good', 'وہ خدمت کرتے ہیں جو نندو کی خدمت کرتے ہیں  میں نے نانڈوس کھانے کو ذايقہ میں زیادہ امیر پایا  لیکن مجموعی طور پر ماحول اچھا تھا']
# ['their food was quality was yummy but quantity was ok the ambiance is up to mark i would suggest this place to go for once', 'ان کا کھانا معیاری تھا لیکن مقدار ٹھیک تھی  ماحول نشان زد ہے  میں اس جگہ کو ایک بار جانے کا مشورہ دوں گا']
# ['very rude managers and not at all polite and flexible', 'بہت بدتمیز مینیجرز اور بالکل بھی شايستہ اور لچکدار نہیں']
# ['awesome food good ambience and service was great highly recommended', 'بہت اچھا کھانا  اچھا ماحول اور سروس بہت اچھا تھا  انتہايی سفارش کی جاتی ہے']
# ['spicy finger linkin grilled chicken but prices are quite high comparatively', 'مسالیدار انگلی لنکن گرلڈ چکن  لیکن قیمتیں نسبتا زیادہ ہیں']
# ['a little bit of nandos touch', 'نندو کا تھوڑا سا لمس']
# ['the peri peri chicken is mouthwatering', 'پیری پیری چکن منہ میں پانی بھرنے والا ہے']
# ['no doubt a healthier option', 'کويی شک نہیں کہ ایک صحت مند اختیار ہے']
# ['delicious food great ambiance and not heavy on pocket', 'مزیدار کھانا بہترین ماحول  اور جیب پر بھاری نہیں']
# ['taste is very good\nserving size seems a bit small but prices are low so it compensate that i guess', 'ذايقہ بہت اچھا ہے سرونگ کا سايز تھوڑا سا چھوٹا لگتا ہے لیکن قیمتیں کم ہیں اس لیے میرا اندازہ ہے کہ اس کی تلافی ہو جاتی ہے']
# ['undoubtedly the food mindblowing and one of its kind\nbut still the food is noticeably overpriced', 'بلاشبہ کھانا دماغ کو اڑانے والا اور اس میں سے ایک قسم کا ہے  لیکن پھر بھی  خوراک نمایاں طور پر زیادہ مہنگی ہے']
# ['tastiest chicken in k town', 'کے ٹاون میں سب سے لذیذ چکن']
# ['we visit this place regularly and their peri bites are the ones to die for', 'ہم باقاعدگی سے اس جگہ کا دورہ کرتے ہیں اور ان کے پیری کاٹنے کی وجہ سے مرنا ہے']
# ['best you can ever have', 'بہترین جو اپ کے پاس ہو سکتا ہے']
# ['not  tasty  juicy the  chicken  i ate  was very  hard', 'مزیدار  رسیلی نہیں  میں نے جو چکن کھایا وہ بہت مشکل تھا']
# ['nice for friends meetup menu is average', 'دوستوں کی ملاقات کے لیے اچھا ہے  مینو اوسط ہے']
# ['translated by google superve foox\n\noriginal\nsuperve foox', 'گوگل کے ذریعہ ترجمہ شدہ  سپرو فوکس  اصل  سپر فوکس']
# ['it was ok could have been better\nthey have to work on their flavors', 'یہ ٹھیک تھا  بہتر ہو سکتا تھا   انہیں اپنے ذايقوں پر کام کرنا ہوگا']
# ['good food but very congested space', 'اچھا کھانا لیکن بہت گنجان جگہ']
# ['excellent prawns taste but very expensive they call it tiger prawns but they are just normal prawns', 'بہترین جھینگے ذايقے میں ہوتے ہیں لیکن بہت مہنگے ہوتے ہیں  اسے ٹايیگر جھینگے کہتے ہیں لیکن یہ صرف عام جھینگے ہیں']
# ['very nice and fresh food', 'بہت عمدہ اور تازہ کھانا']
# ['waiters and manager really need training and courtesy customer service is number one', 'ویٹرس اور مینیجر کو واقعی تربیت اور بشکریہ کی ضرورت ہے  کسٹمر سروس پہلے نمبر پر ہے']
# ['worst place to visit found hair in the food the grill o rice were also stale', 'دیکھنے کے لیے بدترین جگہ  کھانے میں بال ملے  گرل او چاول بھی باسی تھے']
# ['best place food served on time', 'بہترین جگہ  کھانا وقت پر پیش کیا گیا']
# ['good food good service and good presentation', 'اچھا کھانا  اچھی خدمت  اور اچھی پریزنٹیشن']
# ['hygienic and tasty food in town', 'شہر میں صحت بخش اور لذیذ کھانا']
# ['its a good replacement of nandos in a reasonable price space is an issue and its very congested food quality and taste is good', 'یہ ایک مناسب قیمت میں nandos کا ایک اچھا متبادل ہے  خلايی ایک مسيلہ ہے اور یہ بہت بھیڑ ہے  کھانے کا معیار اور ذايقہ اچھا ہے']
# ['if you wanna taste different chicken then grillo is the spot for you simple delicious spices combination', "اگر اپ مختلف چکن کا مزہ چکھنا چاہتے ہیں تو grill'o اپ کے لیے جگہ ہے  سادہ لذیذ مصالحوں کا مجموعہ"]
# ['nice and friendly environment with quality food', 'معیاری کھانے کے ساتھ اچھا اور دوستانہ ماحول']
# ['spicy grill food good experience', 'مسالیدار گرل کھانے کا اچھا تجربہ']
# ['food was good but service was average', 'کھانا اچھا تھا لیکن سروس اوسط تھی']
# ['good place for lunch and dinner costly but good quality', 'دوپہر کے کھانے اور رات کے کھانے کے لیے اچھی جگہ  مہنگی لیکن اچھی کوالٹی']
# ['serves best chicken wings in town', 'ٹاون میں بہترین چکن ونگز پیش کرتا ہے']


# %%
import torch
import torch.nn as nn
import torch.optim as optim
import random

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Encoder RNN
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)  # (1, 1, hidden_size)
        output, hidden = self.gru(embedded, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# Decoder with Attention
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.GRU(self.hidden_size, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, input, hidden, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        attn_weights = torch.softmax(self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        attn_applied = torch.bmm(attn_weights.unsqueeze(0), encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = torch.relu(output)
        output, hidden = self.gru(output, hidden)

        output = torch.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# Hyperparameters
hidden_size = 256
input_lang_size = input_lang.n_words  # Number of words in input language vocabulary
output_lang_size = output_lang.n_words  # Number of words in output language vocabulary

# %%
# Convert sentence to tensor of indexes
def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ')]

def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)

def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

# Training iteration
def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, _ = decoder(decoder_input, decoder_hidden, encoder_outputs)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing
    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, _ = decoder(decoder_input, decoder_hidden, encoder_outputs)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # Detach from history as input

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %%
import time
teacher_forcing_ratio=0.3
def asMinutes(s):
    m = s // 60
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

def trainIters(encoder, decoder, n_iters, print_every=1000, learning_rate=0.01):
    start = time.time()
    print_loss_total = 0  # Reset every print_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    training_pairs = [tensorsFromPair(random.choice(pairs)) for i in range(n_iters)]
    criterion = nn.NLLLoss()

    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]

        loss = train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters), iter, iter / n_iters * 100, print_loss_avg))

# Initialize encoder and decoder
encoder = EncoderRNN(input_lang_size, hidden_size).to(device)
decoder = AttnDecoderRNN(hidden_size, output_lang_size, dropout_p=0.1).to(device)

# Train
trainIters(encoder, decoder, 75000, print_every=5000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-e4182b0aa2fb> in <cell line: 42>()
#      40
#      41 # Train
# ---> 42 trainIters(encoder, decoder, 75000, print_every=5000)
#
# <ipython-input-24-e4182b0aa2fb> in trainIters(encoder, decoder, n_iters, print_every, learning_rate)
#      27         target_tensor = training_pair[1]
#      28
# ---> 29         loss = train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion)
#      30         print_loss_total += loss
#      31
#
# <ipython-input-23-c989d4af9233> in train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length)
#      54                 break
#      55
# ---> 56     loss.backward()
#      57
#      58     encoder_optimizer.step()
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     519                 inputs=inputs,
#     520             )
# --> 521         torch.autograd.backward(
#     522             self, gradient, retain_graph, create_graph, inputs=inputs
#     523         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     287     # some Python versions print out the first line of a multi-line function
#     288     # calls in the traceback and some print out the last line
# --> 289     _engine_run_backward(
#     290         tensors,
#     291         grad_tensors_,
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     767         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     768     try:
# --> 769         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     770             t_outputs, *args, **kwargs
#     771         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei], encoder_hidden)
            encoder_outputs[ei] = encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS token as first input
        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(decoder_input, decoder_hidden, encoder_outputs)
            decoder_attentions[di] = decoder_attention.data

            topv, topi = decoder_output.topk(1)
            if topi.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_lang.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words, decoder_attentions[:di + 1]

# %%
def evaluateRandomly(encoder, decoder, n=10):
    for i in range(n):
        pair = random.choice(pairs)
        print('Input:', pair[0])
        print('Target:', pair[1])
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        print('Predicted:', output_sentence)
        print('')

# %%
# Evaluate the model on random pairs from the dataset
evaluateRandomly(encoder, decoder)

# %%
# Ensure that the necessary imports are included
import unicodedata
import re

# Normalize function to match the training data processing
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"[^\w\s]", "", s)  # Remove punctuation
    return s
def indexesFromSentence(lang, sentence):
    return [lang.word2index.get(word, None) for word in sentence.split(' ') if word in lang.word2index]


def evaluateCustomSentence(sentence):
    # Normalize the input sentence
    normalized_sentence = normalizeString(sentence)

    # Convert the normalized sentence to tensor of indexes
    input_tensor = tensorFromSentence(input_lang, normalized_sentence)

    # Check for None values
    if any(index is None for index in input_tensor):
        print("Input contains unknown words. Please try a different sentence.")
        return

    output_words, attentions = evaluate(encoder, decoder, normalized_sentence)
    output_sentence = ' '.join(output_words)
    print('Input:', normalized_sentence)
    print('Predicted:', output_sentence)

# Test with your own sentence
evaluateCustomSentence("this is a book")
evaluateCustomSentence("i love her")
evaluateCustomSentence("Ass")
# Out:
# Input: this is a book
# Predicted: یہ ایک کتاب ہے <EOS>
# Input: i love her
# Predicted: میں نے میں سے <EOS>
# Input: ass
# Predicted: میں سے <EOS>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import random

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Encoder LSTM
class EncoderLSTM(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderLSTM, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(input_size, hidden_size)
        self.lstm = nn.LSTM(hidden_size, hidden_size)

    def forward(self, input, hidden, cell):
        embedded = self.embedding(input).view(1, 1, -1)  # (1, 1, hidden_size)
        output, (hidden, cell) = self.lstm(embedded, (hidden, cell))
        return output, hidden, cell

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

    def initCell(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

MAX_LENGTH=30
# Decoder with Attention
class AttnDecoderLSTM(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
        super(AttnDecoderLSTM, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.lstm = nn.LSTM(self.hidden_size, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, input, hidden, cell, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        attn_weights = torch.softmax(self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        attn_applied = torch.bmm(attn_weights.unsqueeze(0), encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output, (hidden, cell) = self.lstm(output, (hidden, cell))

        output = torch.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, cell, attn_weights

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

    def initCell(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)


# Hyperparameters
hidden_size = 256
input_lang_size = input_lang.n_words  # Number of words in input language vocabulary
output_lang_size = output_lang.n_words  # Number of words in output language vocabulary

# Convert sentence to tensor of indexes
def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ')]

def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)

def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

# Training iteration
def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()
    encoder_cell = encoder.initCell()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden, encoder_cell = encoder(input_tensor[ei], encoder_hidden, encoder_cell)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden
    decoder_cell = encoder_cell

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_cell, _ = decoder(decoder_input, decoder_hidden, decoder_cell, encoder_outputs)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing
    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_cell, _ = decoder(decoder_input, decoder_hidden, decoder_cell, encoder_outputs)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # Detach from history as input

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

import time
teacher_forcing_ratio = 0.18

def asMinutes(s):
    m = s // 60
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

def trainIters(encoder, decoder, n_iters, print_every=1000, learning_rate=0.01):
    start = time.time()
    print_loss_total = 0  # Reset every print_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    training_pairs = [tensorsFromPair(random.choice(pairs)) for i in range(n_iters)]
    criterion = nn.NLLLoss()

    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]

        loss = train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters), iter, iter / n_iters * 100, print_loss_avg))

# Initialize encoder and decoder
encoder = EncoderLSTM(input_lang_size, hidden_size).to(device)
decoder = AttnDecoderLSTM(hidden_size, output_lang_size, dropout_p=0.1).to(device)

# Train
trainIters(encoder, decoder, 75000, print_every=5000)
# Out:
# 2m 38s (- 36m 54s) (5000 6%) 4.1519
# 5m 19s (- 34m 39s) (10000 13%) 4.1373
# 8m 15s (- 33m 1s) (15000 20%) 4.3799
# 11m 17s (- 31m 3s) (20000 26%) 4.3126
# 14m 19s (- 28m 39s) (25000 33%) 4.1827
# 17m 22s (- 26m 4s) (30000 40%) 4.0525
# 20m 29s (- 23m 25s) (35000 46%) 4.0403
# 23m 35s (- 20m 38s) (40000 53%) 3.9024
# 26m 38s (- 17m 45s) (45000 60%) 3.8002
# 29m 42s (- 14m 51s) (50000 66%) 3.7711
# 32m 49s (- 11m 56s) (55000 73%) 3.7211
# 35m 54s (- 8m 58s) (60000 80%) 3.6277
# 39m 0s (- 6m 0s) (65000 86%) 3.5809
# 42m 6s (- 3m 0s) (70000 93%) 3.5518
# 45m 15s (- 0m 0s) (75000 100%) 3.4956

# %%
def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)
        input_length = input_tensor.size()[0]

        # Initialize hidden and cell states for encoder
        encoder_hidden = encoder.initHidden()
        encoder_cell = encoder.initCell()

        # Initialize encoder outputs to store encoder's hidden states
        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        # Pass through the encoder
        for ei in range(input_length):
            encoder_output, encoder_hidden, encoder_cell = encoder(
                input_tensor[ei], encoder_hidden, encoder_cell
            )
            encoder_outputs[ei] = encoder_output[0, 0]

        # Start decoder with SOS token
        decoder_input = torch.tensor([[SOS_token]], device=device)

        # Decoder hidden and cell states are initialized from encoder's final states
        decoder_hidden = encoder_hidden
        decoder_cell = encoder_cell

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        # Generate output sequence using the decoder
        for di in range(max_length):
            decoder_output, decoder_hidden, decoder_cell, decoder_attention = decoder(
                decoder_input, decoder_hidden, decoder_cell, encoder_outputs
            )
            decoder_attentions[di] = decoder_attention.data

            # Get top predicted word
            topv, topi = decoder_output.topk(1)
            if topi.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_lang.index2word[topi.item()])

            # Use the predicted word as the next input
            decoder_input = topi.squeeze().detach()

        return decoded_words, decoder_attentions[:di + 1]

# %%
def evaluateRandomly(encoder, decoder, n=10):
    for i in range(n):
        pair = random.choice(pairs)
        print('Input:', pair[0])
        print('Target:', pair[1])

        # Ensure that the correct states are passed during evaluation
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)

        print('Predicted:', output_sentence)
        print('')

# %%
evaluateCustomSentence("i love you")
# Out:
# Input: i love you
# Predicted: میں تم سے <EOS>
